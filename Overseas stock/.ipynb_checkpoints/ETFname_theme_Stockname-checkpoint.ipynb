# %%
import pandas as pd 
import re

# %%
etf_stock_df = pd.read_csv('C:/Windows\[2380861]python38_64bit_base/notebooks/Git_hub/korea_/Business Project/dataset/final_stock_df.csv')
etf_stock_df.head()
# Out:
#   etf_names                                     stock_names
# 0      KORP                                     U.S. Dollar
# 1      KORP  Bank of America Corporation 3.419% 20-DEC-2028
# 2      KORP               Morgan Stanley 2.188% 28-APR-2026
# 3      KORP            HSBC Holdings Plc 2.099% 04-JUN-2026
# 4      KORP  Verizon Communications Inc. 4.329% 21-SEP-2028

# %%
theme_etf = pd.read_csv('C:/Windows\[2380861]python38_64bit_base/notebooks/Git_hub/korea_/Business Project/dataset/etf_theme_url.csv')
theme_etf.head()
# Out:
#    Unnamed: 0 Theme                       URL
# 0           0    5G  https://www.etf.com/FIVG
# 1           1    5G  https://www.etf.com/NXTG
# 2           2    5G  https://www.etf.com/TENG
# 3           3    5G  https://www.etf.com/WUGI
# 4           4    5G   https://www.etf.com/CWC

# %%
p=re.compile('[A-Z]+')
m = p.search('https://www.etf.com/FIVG')
m.group(0)
# Out:
# 'FIVG'

# %%
[p.search(for i in theme_etf['URL']]

# %%
p=re.compile('[A-Z]+')
# m = p.search('https://www.etf.com/FIVG')
# m.group(0)
lst=[]
for i in theme_etf['URL']:
    m= p.search(i)
    lst.append(m[0])
    theme_etf['eft_names']=l
# theme_etf.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [30], in <cell line: 5>()
#       6 m= p.search(i)
#       7 lst.append(m[0])
# ----> 8 theme_etf['eft_names']=lst
#
# File C:\Windows\[2380861]python38_64bit_base\python-3.8.9.amd64\lib\site-packages\pandas\core\frame.py:3655, in DataFrame.__setitem__(self, key, value)
#    3652     self._setitem_array([key], value)
#    3653 else:
#    3654     # set column
# -> 3655     self._set_item(key, value)
#
# File C:\Windows\[2380861]python38_64bit_base\python-3.8.9.amd64\lib\site-packages\pandas\core\frame.py:3832, in DataFrame._set_item(self, key, value)
#    3822 def _set_item(self, key, value) -> None:
#    3823     """
#    3824     Add series to DataFrame in specified column.
#    3825
#    (...)
#    3830     ensure homogeneity.
#    3831     """
# -> 3832     value = self._sanitize_column(value)
#    3834     if (
# ...

# %%
lst
# Out:
# ['FIVG',
#  'NXTG',
#  'TENG',
#  'WUGI',
#  'CWC',
#  'ITA',
#  'XAR',
#  'PPA',
#  'DFEN',
#  'SHLD',
#  'AOA',
#  'CLSA',
#  'DUDE',
#  'QPX',
#  'ARMR',
#  'WIZ',
#  'PWS',
#  'EAOA',
#  'BOB',
#  'TAEQ',
#  'MOO',
#  'VEGI',
#  'VEGN',
#  'FTAG',
#  'KROP',
#  'EATV',
#  'YUMY',
#  'JETS',
#  'BIZD',
#  'PSP',
#  'BDCZ',
#  'BDCX',
#  'PEX',
#  'KBWB',
#  'FTXO',
#  'FNGU',
#  'BULZ',
#  'FNGO',
#  'FNGS',
#  'FNGD',
#  'FNGG',
#  'BERZ',
#  'IBB',
#  'XBI',
#  'FBT',
#  'LABU',
#  'BBH',
#  'PBE',
#  'SBIO',
#  'LABD',
#  'BBP',
#  'CHB',
#  'BLOK',
#  'BLCN',
#  'LEGR',
#  'BKCH',
#  'BLKC',
#  'AGG',
#  'BND',
#  'BNDX',
#  'TIP',
#  'LQD',
#  'MUB',
#  'MBB',
#  'SCHP',
#  'TLT',
#  'IUSB',
#  'PFF',
#  'GOVT',
#  'EMB',
#  'VTEB',
#  'HYG',
#  'VMBS',
#  'SCHZ',
#  'FPE',
#  'USHY',
#  'JNK',
#  'SPAB',
#  'USIG',
#  'PGX',
#  'CWB',
#  'FIXD',
#  'HYLB',
#  'SPMB',
#  'ANGL',
#  'BOND',
#  'IAGG',
#  'SPIP',
#  'FALN',
#  'EMLC',
#  'HYD',
#  'VWOB',
#  'TOTL',
#  'FBND',
# ...
