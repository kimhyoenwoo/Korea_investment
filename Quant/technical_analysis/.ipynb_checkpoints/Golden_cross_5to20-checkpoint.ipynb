# %%
import yfinance as yf 
import pandas as pd 
import os 
import matplotlib.pyplot as plt
import talib
import numpy as np 
import FinanceDataReader as fdr

# %% [markdown]
# # load data

# %%
aapl = yf.download('AAPL',start='2020-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data = aapl
data = data.reset_index()
data
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2019-12-31   72.482498   73.419998   72.379997   73.412498   72.139961
# 1   2020-01-02   74.059998   75.150002   73.797501   75.087502   73.785912
# 2   2020-01-03   74.287498   75.144997   74.125000   74.357498   73.068573
# 3   2020-01-06   73.447502   74.989998   73.187500   74.949997   73.650803
# 4   2020-01-07   74.959999   75.224998   74.370003   74.597504   73.304405
# ..         ...         ...         ...         ...         ...         ...
# 615 2022-06-09  147.080002  147.949997  142.529999  142.639999  142.639999
# 616 2022-06-10  140.279999  140.759995  137.059998  137.130005  137.130005
# 617 2022-06-13  132.869995  135.199997  131.440002  131.880005  131.880005
# 618 2022-06-14  133.130005  133.889999  131.479996  132.759995  132.759995
# 619 2022-06-15  134.289993  137.339996  132.160004  135.429993  135.429993
#
#         Volume
# 0    100805600
# 1    135480400
# 2    146322800
# 3    118387200
# 4    108872000
# ..         ...
# 615   69473000
# 616   91437900
# 617  122207100
# 618   84784300
# 619   91205656
#
# [620 rows x 7 columns]

# %%
close_data = data['Close']
close_data
# Out:
# 0       73.412498
# 1       75.087502
# 2       74.357498
# 3       74.949997
# 4       74.597504
#           ...
# 615    142.639999
# 616    137.130005
# 617    131.880005
# 618    132.759995
# 619    135.429993
# Name: Close, Length: 620, dtype: float64

# %%
# 5 이동평균 
ma_5 = close_data.rolling(window=5).mean()
ma_5
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4       74.481000
#           ...
# 615    146.166003
# 616    144.516003
# 617    141.664005
# 618    138.474002
# 619    135.967999
# Name: Close, Length: 620, dtype: float64

# %%
# 20 이동평균 
ma_20 = close_data.rolling(window=20).mean()
ma_20
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#           ...
# 615    144.860502
# 616    144.589002
# 617    143.827502
# 618    143.188503
# 619    142.498002
# Name: Close, Length: 620, dtype: float64

# %%
df= pd.DataFrame()
df['close'] = close_data
df['ma_5'] = ma_5
df['ma_20'] = ma_20
df.head(20)
# Out:
#         close       ma_5      ma_20
# 0   73.412498        NaN        NaN
# 1   75.087502        NaN        NaN
# 2   74.357498        NaN        NaN
# 3   74.949997        NaN        NaN
# 4   74.597504  74.481000        NaN
# 5   75.797501  74.958000        NaN
# 6   77.407501  75.422000        NaN
# 7   77.582497  76.067000        NaN
# 8   79.239998  76.925000        NaN
# 9   78.169998  77.639499        NaN
# 10  77.834999  78.046999        NaN
# 11  78.809998  78.327498        NaN
# 12  79.682503  78.747499        NaN
# 13  79.142502  78.728000        NaN
# 14  79.425003  78.979001        NaN
# 15  79.807503  79.373502        NaN
# 16  79.577499  79.527002        NaN
# 17  77.237503  79.038002        NaN
# 18  79.422501  79.094002        NaN
# 19  81.084999  79.426001  77.631375

# %%
data['close'] = close_data
data['ma_5'] = ma_5
data['ma_20'] = ma_20
data.head(20)
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  
.where(np.sign(diff.shift(1)[1:]) + np.sign(diff[1:]) == 0)[0] + 1
    output = diff[change_idx]
    output = pd.DataFrame(output, columns = ['value'])
    output.value = np.where(output.value >= 0, "buy", "sell")
    
    return output

# %%
# 골든 크로스 5이평이 20이평 돌파시 매수 
for i in range(len(df)):
    #초기값 잡기 
    if i==0:
        # 5이평이 20이평선 밑에 있으면 ,
        df.loc[i.'ma_5'] >= df.loc[i.'ma_20']
        df.loc
    if df['ma_5'][i] > df['ma_20'][i]:
        df.loc[i,'action'] = 'buy'
        df.loc[i.'state'] = 'holding' 
#         df.loc[i,'state'] = 'holding'
    elif df['ma_5'][i] > df['ma_20'][i]:
        df.loc[i,'action'] = 'sell'
#         df.loc[i,'state'] = 'holding'
# Out:
#   Input In [12]
#     df.loc[i.'ma_5'] >= df.loc[i.'ma_20']
#              ^
# SyntaxError: invalid syntax

# %%
# 골든 크로스 5이평이 20이평 돌파시 매수 
for i in range(len(df)):
    # 5이평이 20이평선 밑에 았고
    if df.loc[i,'ma_5'] < df.loc[i,'ma_20']:
        df.loc[i,'ma_5'] < df.loc[i,'ma_20']

# %%
df[df['action'].isin(['buy', 'sell'])]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\Windows\[2380861]python38_64bit_base\python-3.8.9.amd64\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File C:\Windows\[2380861]python38_64bit_base\python-3.8.9.amd64\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\Windows\[2380861]python38_64bit_base\python-3.8.9.amd64\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'action'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 df[df['action'].isin(['buy', 'sell'])]
#
# File C:\Windows\[2380861]python38_64bit_base\python-3.8.9.amd64\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File C:\Windows\[2380861]python38_64bit_base\python-3.8.9.amd64\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'action'

# %%
short_ts = talib.SMA(aapl['Close'],5)[9:]

# %%
long_ts=talib.SMA(aapl['Close'],10)[9:]

# %%
diff = short_ts-long_ts
diff
# Out:
# Date
# 2020-01-14    1.579250
# 2020-01-15    1.544499
# 2020-01-16    1.452749
# 2020-01-17    1.340250
# 2020-01-21    0.901500
#                 ...
# 2022-06-09   -1.134999
# 2022-06-10   -2.120000
# 2022-06-13   -3.195999
# 2022-06-14   -4.778001
# 2022-06-15   -5.956003
# Length: 611, dtype: float64

# %%
diff.shift(1)
# Out:
# Date
# 2020-01-14         NaN
# 2020-01-15    1.579250
# 2020-01-16    1.544499
# 2020-01-17    1.452749
# 2020-01-21    1.340250
#                 ...
# 2022-06-09    0.791002
# 2022-06-10   -1.134999
# 2022-06-13   -2.120000
# 2022-06-14   -3.195999
# 2022-06-15   -4.778001
# Length: 611, dtype: float64

# %%
change_idx = np.where(np.sign(diff.shift(1)[1:]) + np.sign(diff[1:]) == 0)[0] + 1
output = diff[change_idx]
output
# Out:
# Date
# 2020-01-31   -0.154501
# 2020-02-03    0.082749
# 2020-02-05   -0.154500
# 2020-02-07    0.246000
# 2020-02-20   -0.021500
#                 ...
# 2022-04-06   -0.687003
# 2022-05-04    0.028999
# 2022-05-05   -0.380000
# 2022-05-27    0.687000
# 2022-06-09   -1.134999
# Length: 65, dtype: float64

# %%
 np.where(np.sign(diff.shift(1)[1:]) + np.sign(diff[1:]) == 0)[0] + 1
# Out:
# array([ 12,  13,  15,  17,  25,  36,  39,  51,  57,  59,  69,  73, 132,
#        138, 164, 179, 186, 187, 195, 207, 218, 223, 232, 233, 247, 257,
#        265, 270, 274, 293, 299, 306, 322, 323, 324, 325, 326, 341, 347,
#        353, 383, 385, 390, 394, 397, 399, 406, 409, 419, 439, 461, 466,
#        488, 492, 500, 517, 524, 538, 541, 550, 562, 581, 582, 598, 606],
#       dtype=int64)

# %%
def MA_short_long(ts, short = 5, long = 10):
    short_ts = talib.SMA(ts, short)[(long-1):]
    long_ts = talib.SMA(ts, long)[(long-1):]
    
    diff = short_ts-long_ts
    change_idx = np.where(np.sign(diff.shift(1)[1:]) + np.sign(diff[1:]) == 0)[0] + 1
    output = diff[change_idx]
    output = pd.DataFrame(output, columns = ['value'])
    output.value = np.where(output.value >= 0, "buy", "sell")
    
    return output

# %%
np.where(np.sign(diff.shift(1)[1:]) + np.sign(diff[1:]) == 0)[0] +
# Out:
#   Input In [22]
#     np.where(np.sign(diff.shift(1)[1:]) + np.sign(diff[1:]) == 0)[0] +
#                                                                       ^
# SyntaxError: invalid syntax

# %%
##데드 크로스 매도 
def deadcross(short_term_MA, long_term_MA):
    result = [False]
    for i in range(1, len(short_term_MA)):
        if (short_term_MA.iloc[i] <= long_term_MA.iloc[i]) and (short_term_MA.iloc[i-1] > long_term_MA.iloc[i-1]):
            result.append(True)
        else:
            result.append(False)
    
    return result

# %%
buy_idx = np.where(goldencross(ma_5,ma_20))[0]
sell_idx =np.where(deadcross(ma_5,ma_20))[0]

# %%
print(len(ma_5))
print(len(ma_20))
# Out:
# 620
# 620

# %%
data
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2019-12-31   72.482498   73.419998   72.379997   73.412498   72.139961
# 1   2020-01-02   74.059998   75.150002   73.797501   75.087502   73.785912
# 2   2020-01-03   74.287498   75.144997   74.125000   74.357498   73.068573
# 3   2020-01-06   73.447502   74.989998   73.187500   74.949997   73.650803
# 4   2020-01-07   74.959999   75.224998   74.370003   74.597504   73.304405
# ..         ...         ...         ...         ...         ...         ...
# 615 2022-06-09  147.080002  147.949997  142.529999  142.639999  142.639999
# 616 2022-06-10  140.279999  140.759995  137.059998  137.130005  137.130005
# 617 2022-06-13  132.869995  135.199997  131.440002  131.880005  131.880005
# 618 2022-06-14  133.130005  133.889999  131.479996  132.759995  132.759995
# 619 2022-06-15  134.289993  137.339996  132.160004  135.429993  135.429993
#
#         Volume       close        ma_5       ma_20
# 0    100805600   73.412498         NaN         NaN
# 1    135480400   75.087502         NaN         NaN
# 2    146322800   74.357498         NaN         NaN
# 3    118387200   74.949997         NaN         NaN
# 4    108872000   74.597504   74.481000         NaN
# ..         ...         ...         ...         ...
# 615   69473000  142.639999  146.166003  144.860502
# 616   91437900  137.130005  144.516003  144.589002
# 617  122207100  131.880005  141.664005  143.827502
# 618   84784300  132.759995  138.474002  143.188503
# 619   91205656  135.429993  135.967999  142.498002
#
# [620 rows x 10 columns]

# %%
data.iloc[buy_idx,:]# # 골든 크로스 매수 시점
# Out:
# Int64Index([68, 147, 190, 218, 232, 267, 305, 316, 362, 401, 407, 453, 475,
#             527, 560, 610],
#            dtype='int64')

# %%
# Out:
# 68
# 147
# 190
# 218
# 232
# 267
# 305
# 316
# 362
# 401
# 407
# 453
# 475
# 527
# 560
# 610

# %%
data.iloc[sell_idx,:] # # 데드 크로스 매수 시점
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
#
2020-01-07  74.959999  75.224998  74.370003  74.597504  73.304405
#
#       Volume      close    ma_5  ma_20
# 0  100805600  73.412498     NaN    NaN
# 1  135480400  75.087502     NaN    NaN
# 2  146322800  74.357498     NaN    NaN
# 3  118387200  74.949997     NaN    NaN
# 4  108872000  74.597504  74.481    NaN

# %% [markdown]
# # 트레이딩

# %%
# 콜든 크로스 매수 
def goldencross(short_term_MA, long_term_MA):
    result = [False]
    for i in range(1, len(short_term_MA)):
        if (short_term_MA.iloc[i] >= long_term_MA.iloc[i]) and (short_term_MA.iloc[i-1] < long_term_MA.iloc[i-1]):
            result.append(True)
        else:
            result.append(False)
    
    return result


##데드 크로스 매도 
def deadcross(short_term_MA, long_term_MA):
    result = [False]
    for i in range(1, len(short_term_MA)):
        if (short_term_MA.iloc[i] <= long_term_MA.iloc[i]) and (short_term_MA.iloc[i-1] > long_term_MA.iloc[i-1]):
            result.append(True)
        else:
            result.append(False)
    
    return result

# %%
for k in range(len(data)):
    if k in buy_idx:
        data.loc[k,'action'] = 'buy'
    elif k in sell_idx:
        data.loc[k,'action'] = 'sell'
    else:
        data.loc[k,'action'] = ''
        
        
data
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2019-12-31   72.482498   73.419998   72.379997   73.412498   72.139961
# 1   2020-01-02   74.059998   75.150002   73.797501   75.087502   73.785912
# 2   2020-01-03   74.287498   75.144997   74.125000   74.357498   73.068573
# 3   2020-01-06   73.447502   74.989998   73.187500   74.949997   73.650803
# 4   2020-01-07   74.959999   75.224998   74.370003   74.597504   73.304405
# ..         ...         ...         ...         ...         ...         ...
# 615 2022-06-09  147.080002  147.949997  142.529999  142.639999  142.639999
# 616 2022-06-10  140.279999  140.759995  137.059998  137.130005  137.130005
# 617 2022-06-13  132.869995  135.199997  131.440002  131.880005  131.880005
# 618 2022-06-14  133.130005  133.889999  131.479996  132.759995  132.759995
# 619 2022-06-15  134.289993  137.339996  132.160004  135.429993  135.429993
#
#         Volume       close        ma_5       ma_20 action
# 0    100805600   73.412498         NaN         NaN
# 1    135480400   75.087502         NaN         NaN
# 2    146322800   74.357498         NaN         NaN
# 3    118387200   74.949997         NaN         NaN
# 4    108872000   74.597504   74.481000         NaN
# ..         ...         ...         ...         ...    ...
# 615   69473000  142.639999  146.166003  144.860502
# 616   91437900  137.130005  144.516003  144.589002   sell
# 617  122207100  131.880005  141.664005  143.827502
# 618   84784300  132.759995  138.474002  143.188503
# 619   91205656  135.429993  135.967999  142.498002
#
# [620 rows x 11 columns]

# %%
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 60 2020-03-27  63.187500  63.967499  61.762501  61.935001  61.005844
# 61 2020-03-30  62.685001  63.880001  62.349998  63.702499  62.746826
# 62 2020-03-31  63.900002  65.622498  63.000000  63.572498  62.618774
# 63 2020-04-01  61.625000  62.180000  59.782501  60.227501  59.323967
# 64 2020-04-02  60.084999  61.287498  59.224998  61.232498  60.313885
# 65 2020-04-03  60.700001  61.424999  59.742500  60.352501  59.447086
# 66 2020-04-06  62.724998  65.777496  62.345001  65.617500  64.633102
# 67 2020-04-07  67.699997  67.925003  64.750000  64.857498  63.884510
# 68 2020-04-08  65.684998  66.842499  65.307503  66.517502  65.519600
# 75  130015200  69.232498  70.894998  65.080124
# 76  180991600  67.092499  69.960999  65.630124
# 77  116862400  69.025002  69.544499  65.995374
# 78  124814400  68.757500  68.961499  66.364249
# 79  126161200  70.742500  68.970000  66.670874
# 80  117087600  70.792503  69.282001  67.113750
# 81  112004800  69.644997  69.792500  67.410874
# 82  137280800  71.932503  70.374001  67.828875
# 83  183064000  73.449997  71.312500  68.489999
# 84  240616800  72.267502  71.617500  69.041750
# 85  133568000  73.290001  72.117000  69.688625
# 86  147751200  74.389999  73.066000  70.127250
# 87  142333600  75.157501  73.711000  70.642250
# 88  115215200  75.934998  74.208000  71.113124
# 89  133838400  77.532501  75.261000  71.639875
# 90  145946400  78.752502  76.353500  72.161875
# 91  162301200  77.852501  77.046001  72.466375
# 92  200622400  76.912498  77.397000  72.756625
# 93  158929200  77.385002  77.687001  73.042250
# 94  166348400  76.927498  77.566000  73.353625
# 95  135178400  78.739998  77.563499  73.829000
# 96  101729600  78.285004  77.650000  74.388625
# 97  111504800  79.807503  78.229001  74.927750
# 98  102688800  79.212502  78.594501  75.450500
# 99   81803200  79.722504  79.153502  75.899501

# %%
def get_profit(df):
    final_df = df[df['action'].isin(['buy','sell'])]
    final_df = final_df.reset_index(drop=True)
    trading_cnt = final_df.shape[0]
    
    profit = []
    for idx in range(len(final_df)):
        # 매수 action이 들어올 경우 매수 
        if final_df.action[idx] =='buy':
            buy_price = final_df.Close[idx]
        # 첫 action이 매도인 경우
        elif idx == 0 and final_df.action[idx] =='sell':
            continue
        #그 외의 경우 정상 매도 
        else:
            sell_price = final_df.Close[idx]
            profit.append(buy_price - sell_price)
       
    profit_sum = np.sum(profit)
    profit_num = len(profit)
    
    return trading_cnt,profit_sum,profit_num

# %%
final_df.action
# Out:
# 36     sell
# 68      buy
# 144    sell
# 147     buy
# 174    sell
# 190     buy
# 206    sell
# 218     buy
# 229    sell
# 232     buy
# 260    sell
# 267     buy
# 282    sell
# 305     buy
# 308    sell
# 316     buy
# 337    sell
# 362     buy
# 399    sell
# 401     buy
# 405    sell
# 407     buy
# 430    sell
# 453     buy
# 472    sell
# 475     buy
# 511    sell
# 527     buy
# 540    sell
# 560     buy
# 575    sell
# 610     buy
# 616    sell
# Name: action, dtype: object

# %%
get_profit(data)
# Out:
# (33, -55.0050048828125, 16)

# %% [markdown]
# * 국내 데이터적용

# %%
df_krx = fdr.StockListing('KRX')
df_krx.head()
# Out:
#    Symbol  Market    Name           Sector             Industry ListingDate  \
# 0  060310  KOSDAQ      3S         전자부품 제조업          반도체 웨이퍼 캐리어  2002-04-23
# 1  095570   KOSPI  AJ네트웍스  산업용 기계 및 장비 임대업  렌탈(파렛트, OA장비, 건설장비)  2015-08-21
# 2  006840   KOSPI   AK홀딩스           기타 금융업                 지주사업  1999-08-11
# 3  054620  KOSDAQ  APS홀딩스           기타 금융업          인터넷 트래픽 솔루션  2001-12-04
# 4  265520  KOSDAQ   AP시스템    특수 목적용 기계 제조업          디스플레이 제조 장비  2017-04-07
#
#   SettleMonth     Representative                       HomePage Region
# 0         03월                김세완           http://www.3sref.com  서울특별시
# 1         12월           박대현, 손삼달         http://www.ajnet.co.kr  서울특별시
# 2         12월  채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시
# 3         12월                정기로   http://www.apsholdings.co.kr    경기도
# 4         12월                김영주     http://www.apsystems.co.kr    경기도

# %%
df_krx = df_krx.dropna()
df_krx.shape
# Out:
# (2337, 10)

# %%
# symbol를 구하고 , 개별 주식의 데이터 ma 5 + ma_20 구하고 ,
sym_name_lst=df_krx[['Symbol','Name']]
sym_name_lst.head()
# Out:
#    Symbol    Name
# 0  060310      3S
# 1  095570  AJ네트웍스
# 2  006840   AK홀딩스
# 3  054620  APS홀딩스
# 4  265520   AP시스템

# %%
# data_load
raw_df=fdr.DataReader('060310','2021')
raw_df
# Out:
#             Open  High   Low  Close   Volume    Change
# Date
# 2021-01-04  2185  2320  2135   2260   588133  0.043880
# 2021-01-05  2270  2285  2200   2250   410263 -0.004425
# 2021-01-06  2225  2310  2215   2290   570349  0.017778
# 2021-01-07  2290  2340  2240   2290   519777  0.000000
# 2021-01-08  2300  2315  2225   2245   462568 -0.019651
# ...          ...   ...   ...    ...      ...       ...
# 2022-06-10  3150  3370  3135   3195  1452172  0.012678
# 2022-06-13  3085  3135  2990   3000   493079 -0.061033
# 2022-06-14  2860  2985  2860   2895   483227 -0.035000
# 2022-06-15  2880  2925  2750   2815   370354 -0.027634
# 2022-06-16  2815  2910  2815   2910    99167  0.033748
#
# [359 rows x 6 columns]

# %%
raw_df['ma_5'] = raw_df['Close'].rolling(window=5).mean()
ma_5 = raw_df['ma_5']
raw_df['ma_20'] = raw_df['Close'].rolling(window=20).mean()
ma_20 = raw_df['ma_20']

raw_df
# Out:
#             Open  High   Low  Close   Volume    Change    ma_5    ma_20
# Date
# 2021-01-04  2185  2320  2135   2260   588133  0.043880     NaN      NaN
# 2021-01-05  2270  2285  2200   2250   410263 -0.004425     NaN      NaN
# 2021-01-06  2225  2310  2215   2290   570349  0.017778     NaN      NaN
# 2021-01-07  2290  2340  2240   2290   519777  0.000000     NaN      NaN
# 2021-01-08  2300  2315  2225   2245   462568 -0.019651  2267.0      NaN
# ...          ...   ...   ...    ...      ...       ...     ...      ...
# 2022-06-10  3150  3370  3135   3195  1452172  0.012678  3238.0  3224.75
# 2022-06-13  3085  3135  2990   3000   493079 -0.061033  3170.0  3226.75
# 2022-06-14  2860  2985  2860   2895   483227 -0.035000  3099.0  3222.00
# 2022-06-15  2880  2925  2750   2815   370354 -0.027634  3012.0  3211.75
# 2022-06-16  2815  2910  2815   2910    99167  0.033748  2963.0  3203.75
#
# [359 rows x 8 columns]

# %%
# 콜든 크로스 매수 
def goldencross(short_term_MA, long_term_MA):
    result = [False]
    for i in range(1, len(short_term_MA)):
        if (short_term_MA.iloc[i] >= long_term_MA.iloc[i]) and (short_term_MA.iloc[i-1] < long_term_MA.iloc[i-1]):
            result.append(True)
        else:
            result.append(False)
    
    return result


##데드 크로스 매도 
def deadcross(short_term_MA, long_term_MA):
    result = [False]
    for i in range(1, len(short_term_MA)):
        if (short_term_MA.iloc[i] <= long_term_MA.iloc[i]) and (short_term_MA.iloc[i-1] > long_term_MA.iloc[i-1]):
            result.append(True)
        else:
            result.append(False)
    
    return result

# %%
buy_idx = np.where(goldencross(ma_5,ma_20))[0]
sell_idx =np.where(deadcross(ma_5,ma_20))[0]

# %%
for k in range(len(data)):
    if k in buy_idx:
        data.loc[k,'action'] = 'buy'
    elif k in sell_idx:
        data.loc[k,'action'] = 'sell'
    else:
        data.loc[k,'action'] = ''

# %%
def get_profit(df):
    final_df = df[df['action'].isin(['buy','sell'])]
    final_df = final_df.reset_index(drop=True)
    trading_cnt = final_df.shape[0]
    
    profit = []
    for idx in range(len(final_df)):
        # 매수 action이 들어올 경우 매수 
        if final_df.action[idx] =='buy':
            buy_price = final_df.Close[idx]
        # 첫 action이 매도인 경우
        elif idx == 0 and final_df.action[idx] =='sell':
            continue
        #그 외의 경우 정상 매도 
        else:
            sell_price = final_df.Close[idx]
            profit.append(buy_price - sell_price)
       
    profit_sum = np.sum(profit)
    profit_num = len(profit)
    
    return trading_cnt,profit_sum,profit_num

# %%
def get_profit_2(symbol,year):
    raw_df=fdr.DataReader(symbol,year).reset_index()
    
    raw_df['ma_5'] = raw_df['Close'].rolling(window=5).mean()
    ma_5 = raw_df['ma_5']
    raw_df['ma_20'] = raw_df['Close'].rolling(window=20).mean()
    ma_20 = raw_df['ma_20']
    
    buy_idx = np.where(goldencross(ma_5,ma_20))[0]
    sell_idx =np.where(deadcross(ma_5,ma_20))[0]
    
    for k in range(len(raw_df)):
        if k in buy_idx:
            raw_df.loc[k,'action'] = 'buy'
        elif k in sell_idx:
            raw_df.loc[k,'action'] = 'sell'
        else:
            raw_df.loc[k,'action'] = ''

    rst_df = raw_df.copy()
    
    rst = get_profit(rst_df)
    return rst

# %%
get_profit_2('060310','2021')
# Out:
# (19, -205, 9)

# %%
raw_df=fdr.DataReader('060310','2021').reset_index()

raw_df['ma_5'] = raw_df['Close'].rolling(window=5).mean()
ma_5 = raw_df['ma_5']
raw_df['ma_20'] = raw_df['Close'].rolling(window=20).mean()
ma_20 = raw_df['ma_20']

buy_idx = np.where(goldencross(ma_5,ma_20))[0]
sell_idx =np.where(deadcross(ma_5,ma_20))[0]

for k in range(len(raw_df)):
    if k in buy_idx:
        raw_df.loc[k,'action'] = 'buy'
    elif k in sell_idx:
        raw_df.loc[k,'action'] = 'sell'
    else:
        raw_df.loc[k,'action'] = ''

rst_df = raw_df.copy()

rst = get_profit(rst_df)

# %%
raw_df[raw_df['action'].isin(['sell','buy'])]
# Out:
#           Date  Open  High   Low  Close   Volume    Change    ma_5    ma_20  \
# 36  2021-02-25  2425  2500  2425   2445   528684  0.012422  2519.0  2531.25
# 51  2021-03-19  2455  2515  2435   2505   240133  0.014170  2448.0  2436.25
# 57  2021-03-29  2410  2435  2350   2385   194419 -0.010373  2416.0  2416.75
# 61  2021-04-02  2530  2535  2490   2525   207049  0.003976  2443.0  2428.00
# 92  2021-05-18  2790  2810  2650   2780   115442 -0.003584  2866.0  2877.50
# 99  2021-05-28  2895  2925  2870   2905   132202  0.003454  2894.0  2871.00
# 121 2021-06-29  3120  3130  3035   3070   170547 -0.008078  3105.0  3107.25
# 138 2021-07-22  3135  3475  3125   3360  4333328  0.063291  3137.0  3066.75
# 156 2021-08-18  3260  3405  3260   3385   288199  0.025758  3496.0  3533.00
# 168 2021-09-03  3520  3655  3515   3640   396366  0.034091  3508.0  3471.75
# 189 2021-10-08  3730  3850  3725   3790   180495  0.020188  3790.0  3826.75
# 193 2021-10-15  3990  4070  3955   4065   359604  0.017522  3877.0  3845.75
# 208 2021-11-05  4080  4130  3960   3985   295209 -0.031592  4118.0  4118.75
# 250 2022-01-05  3425  3445  3325   3360   202973  0.013575  3326.0  3321.75
# 257 2022-01-14  3215  3220  3120   3120   135147 -0.028037  3247.0  3281.25
# 277 2022-02-16  2820  3185  2820   3035  1040084  0.080071  2901.0  2894.00
# 319 2022-04-19  3450  3485  3430   3440    85850  0.002915  3426.0  3447.75
# 342 2022-05-23  3510  3575  3330   3355  3260046 -0.038682  3237.0  3177.00
# 355 2022-06-13  3085  3135  2990   3000   493079 -0.061033  3170.0  3226.75
#
#     action
# 36    sell
# 51     buy
# 57    sell
# 61     buy
# 92    sell
# 99     buy
# 121   sell
# 138    buy
# 156   sell
# 168    buy
# 189   sell
# 193    buy
# 208   sell
# 250    buy
# 257   sell
# 277    buy
# 319   sell
# 342    buy
# 355   sell

# %%
# lst_value =
lst = []
lst_2 = []
for idx, idx_2 in zip(sym_name_lst.Symbol[:20],sym_name_lst.Name[:20]):
    rst = get_profit_2(idx,'2021')[1]
    lst.append(rst)
    name =idx_2
    lst_2.append(name)

# %%
sym_name_lst.Symbol[:100]
# Out:
# 0       060310
# 1       095570
# 2       006840
# 3       054620
# 4       265520
#          ...
# 1361    119650
# 1362    044180
# 1363    092220
# 1364    151860
# 1365    046440
# Name: Symbol, Length: 100, dtype: object

# %%
rst
# Out:
# -9150

# %%
lst
# Out:
# [-205,
#  -875,
#  -4100,
#  -760,
#  5500,
#  -2900,
#  800,
#  8500,
#  0.0,
#  -290,
#  58500,
#  2075,
#  8000,
#  650,
#  9100,
#  -650,
#  27500,
#  1040,
#  40000,
#  -9150]

# %%
lst_2
# Out:
# ['3S',
#  'AJ네트웍스',
#  'AK홀딩스',
#  'APS홀딩스',
#  'AP시스템',
#  'AP위성',
#  'BGF',
#  'BGF리테일',
#  'BNGT',
#  'BNK금융지주',
#  'BYC',
#  'CBI',
#  'CJ',
#  'CJ CGV',
#  'CJ ENM',
#  'CJ 바이오사이언스',
#  'CJ대한통운',
#  'CJ씨푸드',
#  'CJ제일제당',
#  'CJ프레시웨이']

# %%
pd.DataFrame({'name':lst_2,'profit':lst})
# Out:
#           name   profit
# 0           3S   -205.0
# 1       AJ네트웍스   -875.0
# 2        AK홀딩스  -4100.0
# 3       APS홀딩스   -760.0
# 4        AP시스템   5500.0
# 5         AP위성  -2900.0
# 6          BGF    800.0
# 7       BGF리테일   8500.0
# 8         BNGT      0.0
# 9      BNK금융지주   -290.0
# 10         BYC  58500.0
# 11         CBI   2075.0
# 12          CJ   8000.0
# 13      CJ CGV    650.0
# 14      CJ ENM   9100.0
# 15  CJ 바이오사이언스   -650.0
# 16      CJ대한통운  27500.0
# 17       CJ씨푸드   1040.0
# 18      CJ제일제당  40000.0
# 19     CJ프레시웨이  -9150.0
